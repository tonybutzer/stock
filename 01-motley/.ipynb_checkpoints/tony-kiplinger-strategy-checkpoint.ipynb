# %%
# !ls /data
# Out:
# ira.csv        motley.csv	      taxable.csv	tonyindex.csv
# kiplinger.csv  PortfolioDownload.csv  tonydividend.csv	tonyira.csv

# %%
import pandas as pd

# read csv file
cars = pd.read_csv("/data/taxable.csv")

# display DataFrame
#print(cars)

# %%
#cars

# %%
# read csv file
motley = pd.read_csv("/data/kiplinger.csv")

# display DataFrame
motley
# Out:
#    Symbol  Last Price $  Change $  Change %  Qty #  Price Paid $  \
# 0    AMZN       3675.74    164.76      4.69    4.0      250.9850
# 1     VMC        171.03      0.05      0.03    1.0      170.5600
# 2     MLM        348.54     -1.05     -0.30    1.0      348.4400
# 3     AMD         94.47     -0.23     -0.24    1.0       94.9300
# 4    BKLN         22.14     -0.03     -0.14  100.0       22.2000
# 5      DE        349.45     -3.05     -0.87    2.0      352.5000
# 6      GS        369.86     -4.30     -1.15    2.0      373.2300
# 7    ARKK        127.24     -0.91     -0.71   10.0      128.1000
# 8     NUE         92.55     -3.97     -4.11    4.0       96.0100
# 9     PPL         28.17     -0.08     -0.28  190.0       26.0501
# 10    ADM         59.45     -1.18     -1.95   20.0       60.2800
# 11    URI        311.43     -8.14     -2.55    2.0      319.7900
# 12     FB        352.78     -1.92     -0.54   10.0      160.0525
# 13   ISCG         51.24     -0.49     -0.95   60.0       26.3400
# 14   BYND        145.56     -5.25     -3.48   13.0      139.6684
# 15    AMJ         19.60     -0.27     -1.36  258.0       19.3650
# 16     MS         90.21     -1.82     -1.98   50.0       44.8000
# 17    USB         56.01     -1.56     -2.71  110.0       43.0739
# 18   ALLY         49.60     -0.95     -1.88  260.0       21.5054
# 19    CVS         81.18     -1.25     -1.52  220.0       64.1690
#
#     Day's Gain $  Total Gain $  Total Gain %   Value $  Dividend Yield %
# 0         659.04    13694.5200     1357.9906  14702.96            0.0000
# 1           0.47        0.4700        0.2756    171.03            0.8656
# 2           0.10        0.1000        0.0287    348.54            0.6522
# 3          -0.46       -0.4600       -0.4846     94.47            0.0000
# 4          -6.00       -6.0000       -0.2703   2214.00            3.1990
# 5          -6.10       -6.1000       -0.8652    698.90            1.0213
# 6          -6.74       -6.7400       -0.9029    739.72            1.3363
# 7          -8.60       -8.6000       -0.6714   1272.40            0.0000
# 8         -13.84      -13.8400       -3.6038    370.20            1.6784
# 9         -15.20      383.8043        7.7248   5352.30            5.8761
# 10        -16.60      -16.6000       -1.3769   1189.00            2.4410
# 11        -16.72      -16.7200       -2.6142    622.86            0.0000
# 12        -19.20     1927.2750      120.4152   3527.80            0.0000
# 13        -29.40     1494.0000       94.5330   3074.40            0.2289
# 14        -68.25       76.5905        4.2183   1892.28            0.0000
# 15        -69.66       60.6300        1.2135   5056.80            6.9839
# 16        -91.00     2268.2679      101.1612   4510.50            1.5212
# 17       -171.60     1417.9690       29.8952   6161.10            2.9182
# 18       -247.00     7304.5900      130.6395  12896.00            1.5035
# 19       -275.00     3712.4290       26.2415  17859.60            2.4263

# %%
cdf  = pd.DataFrame()
for sym in motley['Symbol']:
    #print(sym)
    mdf = cars.loc[cars['Symbol'] == sym]
    #print(mdf)
    cdf = cdf.append(mdf)

# %%
cdf
# Out:
#    Symbol  Last Price $  Change $  Change %  Qty #  Price Paid $  \
# 0    AMZN       3675.74    164.76      4.69    4.0      250.9850
# 11    VMC        171.03      0.05      0.03    1.0      170.5600
# 12    MLM        348.54     -1.05     -0.30    1.0      348.4400
# 14    AMD         94.47     -0.23     -0.24    1.0       94.9300
# 19   BKLN         22.14     -0.03     -0.14  100.0       22.2000
# 20     DE        349.45     -3.05     -0.87    2.0      352.5000
# 21     GS        369.86     -4.30     -1.15    2.0      373.2300
# 22   ARKK        127.24     -0.91     -0.71   10.0      128.1000
# 28    NUE         92.55     -3.97     -4.11    4.0       96.0100
# 29    PPL         28.17     -0.08     -0.28  190.0       26.0501
# 30    ADM         59.45     -1.18     -1.95   20.0       60.2800
# 31    URI        311.43     -8.14     -2.55    2.0      319.7900
# 32     FB        352.78     -1.92     -0.54   10.0      160.0525
# 34   ISCG         51.24     -0.49     -0.95   60.0       26.3400
# 39   BYND        145.56     -5.25     -3.48   13.0      139.6684
# 40    AMJ         19.60     -0.27     -1.36  258.0       19.3650
# 42     MS         90.21     -1.82     -1.98   50.0       44.8000
# 44    USB         56.01     -1.56     -2.71  110.0       43.0739
# 46   ALLY         49.60     -0.95     -1.88  260.0       21.5054
# 47    CVS         81.18     -1.25     -1.52  220.0       64.1690
#
#     Day's Gain $  Total Gain $  Total Gain %   Value $  Dividend Yield %
# 0         659.04    13694.5200     1357.9906  14702.96            0.0000
# 11          0.47        0.4700        0.2756    171.03            0.8656
# 12          0.10        0.1000        0.0287    348.54            0.6522
# 14         -0.46       -0.4600       -0.4846     94.47            0.0000
# 19         -6.00       -6.0000       -0.2703   2214.00            3.1990
# 20         -6.10       -6.1000       -0.8652    698.90            1.0213
# 21         -6.74       -6.7400       -0.9029    739.72            1.3363
# 22         -8.60       -8.6000       -0.6714   1272.40            0.0000
# 28        -13.84      -13.8400       -3.6038    370.20            1.6784
# 29        -15.20      383.8043        7.7248   5352.30            5.8761
# 30        -16.60      -16.6000       -1.3769   1189.00            2.4410
# 31        -16.72      -16.7200       -2.6142    622.86            0.0000
# 32        -19.20     1927.2750      120.4152   3527.80            0.0000
# 34        -29.40     1494.0000       94.5330   3074.40            0.2289
# 39        -68.25       76.5905        4.2183   1892.28            0.0000
# 40        -69.66       60.6300        1.2135   5056.80            6.9839
# 42        -91.00     2268.2679      101.1612   4510.50            1.5212
# 44       -171.60     1417.9690       29.8952   6161.10            2.9182
# 46       -247.00     7304.5900      130.6395  12896.00            1.5035
# 47       -275.00     3712.4290       26.2415  17859.60            2.4263

# %%
tdf = cdf.sum(axis=0)

# %%
tdf
# Out:
# Symbol              AMZNVMCMLMAMDBKLNDEGSARKKNUEPPLADMURIFBISCGBYN...
# Last Price $                                                  6496.25
# Change $                                                       128.36
# Change %                                                        -22.0
# Qty #                                                          1318.0
# Price Paid $                                                2762.0493
# Day's Gain $                                                  -401.76
# Total Gain $                                               32265.5857
# Total Gain %                                                1863.5478
# Value $                                                      82754.86
# Dividend Yield %                                              32.6519
# dtype: object

# %%
total_gain = tdf['Total Gain $']

# %%
total_gain
# Out:
# 32265.5857

# %%
value = tdf['Value $']

# %%
value
# Out:
# 82754.86

# %%
pct = total_gain/(value - total_gain)*100

# %%
pct
# Out:
# 63.905821874726364

# %%
cdf['income'] = cdf['Dividend Yield %']/100 * cdf['Value $']

# %%
cdf
# Out:
#    Symbol  Last Price $  Change $  Change %  Qty #  Price Paid $  \
# 0    AMZN       3675.74    164.76      4.69    4.0      250.9850
# 11    VMC        171.03      0.05      0.03    1.0      170.5600
# 12    MLM        348.54     -1.05     -0.30    1.0      348.4400
# 14    AMD         94.47     -0.23     -0.24    1.0       94.9300
# 19   BKLN         22.14     -0.03     -0.14  100.0       22.2000
# 20     DE        349.45     -3.05     -0.87    2.0      352.5000
# 21     GS        369.86     -4.30     -1.15    2.0      373.2300
# 22   ARKK        127.24     -0.91     -0.71   10.0      128.1000
# 28    NUE         92.55     -3.97     -4.11    4.0       96.0100
# 29    PPL         28.17     -0.08     -0.28  190.0       26.0501
# 30    ADM         59.45     -1.18     -1.95   20.0       60.2800
# 31    URI        311.43     -8.14     -2.55    2.0      319.7900
# 32     FB        352.78     -1.92     -0.54   10.0      160.0525
# 34   ISCG         51.24     -0.49     -0.95   60.0       26.3400
# 39   BYND        145.56     -5.25     -3.48   13.0      139.6684
# 40    AMJ         19.60     -0.27     -1.36  258.0       19.3650
# 42     MS         90.21     -1.82     -1.98   50.0       44.8000
# 44    USB         56.01     -1.56     -2.71  110.0       43.0739
# 46   ALLY         49.60     -0.95     -1.88  260.0       21.5054
# 47    CVS         81.18     -1.25     -1.52  220.0       64.1690
#
#     Day's Gain $  Total Gain $  Total Gain %   Value $  Dividend Yield %  \
# 0         659.04    13694.5200     1357.9906  14702.96            0.0000
# 11          0.47        0.4700        0.2756    171.03            0.8656
# 12          0.10        0.1000        0.0287    348.54            0.6522
# 14         -0.46       -0.4600       -0.4846     94.47            0.0000
# 19         -6.00       -6.0000       -0.2703   2214.00            3.1990
# 20         -6.10       -6.1000       -0.8652    698.90            1.0213
# 21         -6.74       -6.7400       -0.9029    739.72            1.3363
# 22         -8.60       -8.6000       -0.6714   1272.40            0.0000
# 28        -13.84      -13.8400       -3.6038    370.20            1.6784
# 29        -15.20      383.8043        7.7248   5352.30            5.8761
# 30        -16.60      -16.6000       -1.3769   1189.00            2.4410
# 31        -16.72      -16.7200       -2.6142    622.86            0.0000
# 32        -19.20     1927.2750      120.4152   3527.80            0.0000
# 34        -29.40     1494.0000       94.5330   3074.40            0.2289
# 39        -68.25       76.5905        4.2183   1892.28            0.0000
# 40        -69.66       60.6300        1.2135   5056.80            6.9839
# 42        -91.00     2268.2679      101.1612   4510.50            1.5212
# 44       -171.60     1417.9690       29.8952   6161.10            2.9182
# 46       -247.00     7304.5900      130.6395  12896.00            1.5035
# 47       -275.00     3712.4290       26.2415  17859.60            2.4263
#
#         income
# 0     0.000000
# 11    1.480436
# 12    2.273178
# 14    0.000000
# 19   70.825860
# 20    7.137866
# 21    9.884878
# 22    0.000000
# 28    6.213437
# 29  314.506500
# 30   29.023490
# 31    0.000000
# 32    0.000000
# 34    7.037302
# 39    0.000000
# 40  353.161855
# 42   68.613726
# 44  179.793220
# 46  193.891360
# 47  433.327475

# %%
cdf.sum(axis=0)['income']
# Out:
# 1677.17058252
