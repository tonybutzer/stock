# %%
import pandas as pd
import requests
import json

# %%
#symbol = 'CR'
symbol = 'F'
url = 'https://financialmodelingprep.com/api/v3/financial-ratios/' + symbol
fr = requests.get(url)

# %%
fr = fr.json()
fr
# Out:
# {'symbol': 'F',
#  'ratios': [{'date': '2018-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '0.8469',
#     'priceToBookRatio': '0.8469',
#     'priceToSalesRatio': '0.1898',
#     'priceEarningsRatio': '8.2258',
#     'receivablesTurnover': '14.322286735149621',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '2.0258',
#     'priceCashFlowRatio': '1.9596377592874',
#     'priceEarningsToGrowthRatio': '8.0058956812661',
#     'priceSalesRatio': '0.18359764011036',
#     'dividendYield': '0.098683053688935',
#     'enterpriseValueMultiple': '9.74851813799099',
#     'priceFairValue': '0.81926078203316'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.8497804483475849',
#     'ebtperEBIT': '0.9958573072497123',
#     'ebitperRevenue': '0.027099003355411693',
#     'grossProfitMargin': '0.09109506168219636',
#     'operatingProfitMargin': '0.027099003355411693',
#     'pretaxProfitMargin': '0.026986740510671205',
#     'netProfitMargin': '0.022932804450598112',
#     'effectiveTaxRate': '0.15021955165241507',
#     'returnOnAssets': '0.014333047477976145',
#     'returnOnEquity': '0.10233218301235668',
#     'returnOnCapitalEmployed': '0.0269924396319834',
#     'nIperEBT': '0.8497804483475849',
#     'eBTperEBIT': '0.9958573072497123',
#     'eBITperRevenue': '0.027099003355411693'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '14.322286735149621',
#     'payablesTurnover': '6.771933085501859',
#     'inventoryTurnover': '12.988591800356506',
#     'fixedAssetTurnover': '4.4319199513516505',
#     'assetTurnover': '0.625001949013799'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.1996463288304784',
#     'quickRatio': '0.472391675124779',
#     'cashRatio': '0.1749312015402484',
#     'daysOfSalesOutstanding': '25.484757200414126',
#     'daysOfInventoryOutstanding': '28.101583729036864',
#     'operatingCycle': '53.58634092945099',
#     'daysOfPayablesOutstanding': '53.898937776191914',
#     'cashConversionCycle': '-28.414180575777788'},
#    'debtRatios': {'debtRatio': '0.8599360723473922',
#     'debtEquityRatio': '6.139597016586887',
#     'longtermDebtToCapitalization': '0.7121271601278651',
#     'totalDebtToCapitalization': '8.888700000029079E10',
#     'interestCoverage': '6.684615384615385',
#     'cashFlowToDebtRatio': '0.10724943954992647',
#     'companyEquityMultiplier': '7.139597016586887'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '3.7764',
#     'freeCashFlowPerShare': '1.8193',
#     'cashPerShare': '4.2027',
#     'payoutRatio': '0.7900462333423987',
#     'receivablesTurnover': '14.322286735149621',
#     'operatingCashFlowSalesRatio': '0.09368958076064314',
#     'freeCashFlowOperatingCashFlowRatio': '0.48176008520836106',
#     'cashFlowCoverageRatios': '0.10724943954992647',
#     'shortTermCoverageRatios': '0.29351882608100976',
#     'capitalExpenditureCoverageRatios': '1.9296082209377008',
#     'dividendpaidAndCapexCoverageRatios': '1.4052385406922356',
#     'dividendPayoutRatio': '0.7900462333424'}},
#   {'date': '2017-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '1.4135',
#     'priceToBookRatio': '1.4135',
#     'priceToSalesRatio': '0.3208',
#     'priceEarningsRatio': '6.5258',
#     'receivablesTurnover': '14.791584111708652',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '2.779',
#     'priceCashFlowRatio': '2.5083938095824',
#     'priceEarningsToGrowthRatio': '5.8714130614672',
#     'priceSalesRatio': '0.28953343865262',
#     'dividendYield': '0.056926463092072',
#     'enterpriseValueMultiple': '-0.15426781519185592',
#     'priceFairValue': '1.2758416543427'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.9359763605023393',
#     'ebtperEBIT': '0.9968090328915071',
#     'ebitperRevenue': '0.05197224064907894',
#     'grossProfitMargin': '0.10422513650048477',
#     'operatingProfitMargin': '0.05197224064907894',
#     'pretaxProfitMargin': '0.05180639893861305',
#     'netProfitMargin': '0.048489564729295304',
#     'effectiveTaxRate': '0.06402363949766067',
#     'returnOnAssets': '0.029487060137776952',
#     'returnOnEquity': '0.2178847807394669',
#     'returnOnCapitalEmployed': '0.0499240233321896',
#     'nIperEBT': '0.9359763605023393',
#     'eBTperEBIT': '0.9968090328915071',
#     'eBITperRevenue': '0.05197224064907894'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '14.791584111708652',
#     'payablesTurnover': '6.0319560175242675',
#     'inventoryTurnover': '13.66507735720541',
#     'fixedAssetTurnover': '4.437852067823478',
#     'assetTurnover': '0.6081114627940173'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.2251797040169132',
#     'quickRatio': '0.5235306553911205',
#     'cashRatio': '0.1954756871035941',
#     'daysOfSalesOutstanding': '24.676194060315353',
#     'daysOfInventoryOutstanding': '26.710423253296874',
#     'operatingCycle': '51.38661731361223',
#     'daysOfPayablesOutstanding': '60.51105129738813',
#     'cashConversionCycle': '-35.834857237072775'},
#    'debtRatios': {'debtRatio': '0.864666728728356',
#     'debtEquityRatio': '6.389165950128977',
#     'longtermDebtToCapitalization': '0.2649320551985674',
#     'totalDebtToCapitalization': '1.2575000000066036E10',
#     'interestCoverage': '15.669230769230769',
#     'cashFlowToDebtRatio': '1.1358985625510012',
#     'companyEquityMultiplier': '7.389165950128977'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '4.5555',
#     'freeCashFlowPerShare': '2.781',
#     'cashPerShare': '4.6552',
#     'payoutRatio': '0.3399105498553012',
#     'receivablesTurnover': '14.791584111708652',
#     'operatingCashFlowSalesRatio': '0.1154258304842578',
#     'freeCashFlowOperatingCashFlowRatio': '0.6104664014146772',
#     'cashFlowCoverageRatios': '1.1358985625510012',
#     'shortTermCoverageRatios': '5.392133492252682',
#     'capitalExpenditureCoverageRatios': '2.5671726486026385',
#     'dividendpaidAndCapexCoverageRatios': '1.8785425101214575',
#     'dividendPayoutRatio': '0.33423877894192'}},
#   {'date': '2016-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '1.7151',
#     'priceToBookRatio': '1.7151',
#     'priceToSalesRatio': '0.3296',
#     'priceEarningsRatio': '10.8534',
#     'receivablesTurnover': '13.673212033867772',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '2.5204',
#     'priceCashFlowRatio': '2.1543939244969',
#     'priceEarningsToGrowthRatio': '9.3189626065077',
#     'priceSalesRatio': '0.28171751911241',
#     'dividendYield': '0.078943578895557',
#     'enterpriseValueMultiple': '1.289241281505834E-4',
#     'priceFairValue': '1.4660514021688'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.677376565954311',
#     'ebtperEBIT': '0.9983814008240142',
#     'ebitperRevenue': '0.04476943346508564',
#     'grossProfitMargin': '0.10745718050065876',
#     'operatingProfitMargin': '0.04476943346508564',
#     'pretaxProfitMargin': '0.0446969696969697',
#     'netProfitMargin': '0.030276679841897233',
#     'effectiveTaxRate': '0.322623434045689',
#     'returnOnAssets': '0.01931490096700581',
#     'returnOnEquity': '0.15755913609873157',
#     'returnOnCapitalEmployed': '0.04602153450260717',
#     'nIperEBT': '0.677376565954311',
#     'eBTperEBIT': '0.9983814008240142',
#     'eBITperRevenue': '0.04476943346508564'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '13.673212033867772',
#     'payablesTurnover': '6.36213373403456',
#     'inventoryTurnover': '15.22679253764891',
#     'fixedAssetTurnover': '4.733100523821402',
#     'assetTurnover': '0.6379464679702964'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.2013712741329847',
#     'quickRatio': '0.5530399530355224',
#     'cashRatio': '0.1761721735470365',
#     'daysOfSalesOutstanding': '26.69453227931489',
#     'daysOfInventoryOutstanding': '23.970905172413794',
#     'operatingCycle': '50.66543745172868',
#     'daysOfPayablesOutstanding': '57.37068965517241',
#     'cashConversionCycle': '-30.676157375857525'},
#    'debtRatios': {'debtRatio': '0.8774117360296868',
#     'debtEquityRatio': '7.157387727116901',
#     'longtermDebtToCapitalization': '0.31189847140969995',
#     'totalDebtToCapitalization': '1.3222000000059565E10',
#     'interestCoverage': '3.1046139789858382',
#     'cashFlowToDebtRatio': '1.2442320990758786',
#     'companyEquityMultiplier': '8.157387727116902'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '4.9953',
#     'freeCashFlowPerShare': '3.2358',
#     'cashPerShare': '4.0026',
#     'payoutRatio': '0.7345517841601392',
#     'receivablesTurnover': '13.673212033867772',
#     'operatingCashFlowSalesRatio': '0.1303820816864295',
#     'freeCashFlowOperatingCashFlowRatio': '0.6467259498787389',
#     'cashFlowCoverageRatios': '1.2442320990758786',
#     'shortTermCoverageRatios': '7.371322160148976',
#     'capitalExpenditureCoverageRatios': '2.8306636155606406',
#     'dividendpaidAndCapexCoverageRatios': '1.9089506172839505',
#     'dividendPayoutRatio': '0.73567225975158'}},
#   {'date': '2015-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '1.9523',
#     'priceToBookRatio': '1.9523',
#     'priceToSalesRatio': '0.3739',
#     'priceEarningsRatio': '7.5753',
#     'receivablesTurnover': '1.6490941769304561',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '3.4462',
#     'priceCashFlowRatio': '2.7544387051976',
#     'priceEarningsToGrowthRatio': '6.0617825078714',
#     'priceSalesRatio': '0.29883739038056',
#     'dividendYield': '0.05325156466911',
#     'enterpriseValueMultiple': '-0.07865846964540564',
#     'priceFairValue': '1.5604190500152'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.7190364735712893',
#     'ebtperEBIT': '1.000195083886071',
#     'ebitperRevenue': '0.06854865670843419',
#     'grossProfitMargin': '1.0810922852672542',
#     'operatingProfitMargin': '0.06854865670843419',
#     'pretaxProfitMargin': '0.06856202944676981',
#     'netProfitMargin': '0.04929859987429626',
#     'effectiveTaxRate': '0.28096352642871075',
#     'returnOnAssets': '0.03277981549405357',
#     'returnOnEquity': '0.25741917463864256',
#     'returnOnCapitalEmployed': '0.055332768419518674',
#     'nIperEBT': '0.7190364735712893',
#     'eBTperEBIT': '1.000195083886071',
#     'eBITperRevenue': '0.06854865670843419'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.6490941769304561',
#     'payablesTurnover': '-0.6327212020033389',
#     'inventoryTurnover': '-1.4578675321553072',
#     'fixedAssetTurnover': '4.958326426416471',
#     'assetTurnover': '0.6649238635100589'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.0738536043989306',
#     'quickRatio': '3.1060888866468246',
#     'cashRatio': '0.35998587499369417',
#     'daysOfSalesOutstanding': '221.33362976236646',
#     'daysOfInventoryOutstanding': '-250.36568271767808',
#     'operatingCycle': '-29.032052955311627',
#     'daysOfPayablesOutstanding': '-576.8733509234828',
#     'cashConversionCycle': '798.2069806858492'},
#    'debtRatios': {'debtRatio': '0.8726597754807158',
#     'debtEquityRatio': '6.852978143984359',
#     'longtermDebtToCapitalization': '0.27857538663039644',
#     'totalDebtToCapitalization': '1.1060000000042887E10',
#     'interestCoverage': '3.558486636584519',
#     'cashFlowToDebtRatio': '1.2594438819222682',
#     'companyEquityMultiplier': '7.852978143984359'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '4.0886',
#     'freeCashFlowPerShare': '2.2753',
#     'cashPerShare': '3.5962',
#     'payoutRatio': '0.32279940322799405',
#     'receivablesTurnover': '1.6490941769304561',
#     'operatingCashFlowSalesRatio': '0.10811858944356036',
#     'freeCashFlowOperatingCashFlowRatio': '0.554978354978355',
#     'cashFlowCoverageRatios': '1.2594438819222682',
#     'shortTermCoverageRatios': '9.089376053962901',
#     'capitalExpenditureCoverageRatios': '2.247081712062257',
#     'dividendpaidAndCapexCoverageRatios': '1.6885964912280702',
#     'dividendPayoutRatio': '0.32279940322799'}},
#   {'date': '2014-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '2.4411',
#     'priceToBookRatio': '2.4411',
#     'priceToSalesRatio': '0.414',
#     'priceEarningsRatio': '50.0',
#     'receivablesTurnover': '1.776294214101663',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '4.1121',
#     'priceCashFlowRatio': '3.1583803473761',
#     'priceEarningsToGrowthRatio': '37.220652883335',
#     'priceSalesRatio': '0.31801483720084',
#     'dividendYield': '0.042602763732211',
#     'enterpriseValueMultiple': '0.2606884827879303',
#     'priceFairValue': '1.8748925320969'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.7338245452452222',
#     'ebtperEBIT': '1.0002303086135422',
#     'ebitperRevenue': '0.030136663034349687',
#     'grossProfitMargin': '1.077132366720573',
#     'operatingProfitMargin': '0.030136663034349687',
#     'pretaxProfitMargin': '0.030143603767429916',
#     'netProfitMargin': '0.022120116326686423',
#     'effectiveTaxRate': '0.26617545475477783',
#     'returnOnAssets': '0.015283392558277825',
#     'returnOnEquity': '0.1284821608546664',
#     'returnOnCapitalEmployed': '0.025780939205196564',
#     'nIperEBT': '0.7338245452452222',
#     'eBTperEBIT': '1.0002303086135422',
#     'eBITperRevenue': '0.030136663034349687'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.776294214101663',
#     'payablesTurnover': '-0.5887370205552024',
#     'inventoryTurnover': '-1.412789219425375',
#     'fixedAssetTurnover': '4.78248024961827',
#     'assetTurnover': '0.6909273139689345'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.0083275157075895',
#     'quickRatio': '2.7177371098035303',
#     'cashRatio': '0.2682008576842525',
#     'daysOfSalesOutstanding': '205.4839773176843',
#     'daysOfInventoryOutstanding': '-258.35417978943576',
#     'operatingCycle': '-52.87020247175147',
#     'daysOfPayablesOutstanding': '-619.9712048951678',
#     'cashConversionCycle': '825.4551822128522'},
#    'debtRatios': {'debtRatio': '0.8810465791000686',
#     'debtEquityRatio': '7.406651884700665',
#     'longtermDebtToCapitalization': '0.31341341895482727',
#     'totalDebtToCapitalization': '1.1323000000064745E10',
#     'interestCoverage': '3.7560553633217992',
#     'cashFlowToDebtRatio': '1.0494068287037037',
#     'companyEquityMultiplier': '8.406651884700665'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '3.7693',
#     'freeCashFlowPerShare': '1.8302',
#     'cashPerShare': '2.795',
#     'payoutRatio': '0.6124882334483841',
#     'receivablesTurnover': '1.776294214101663',
#     'operatingCashFlowSalesRatio': '0.10068921479486663',
#     'freeCashFlowOperatingCashFlowRatio': '0.4855586958020266',
#     'cashFlowCoverageRatios': '1.0494068287037037',
#     'shortTermCoverageRatios': '5.800479808076769',
#     'capitalExpenditureCoverageRatios': '1.9438563580329626',
#     'dividendpaidAndCapexCoverageRatios': '1.5408390865639936',
#     'dividendPayoutRatio': '1.5857026807474'}},
#   {'date': '2013-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '2.3308',
#     'priceToBookRatio': '2.3308',
#     'priceToSalesRatio': '0.4143',
#     'priceEarningsRatio': '5.0757',
#     'receivablesTurnover': '1.8961680928227564',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '5.8275',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '0.17354663619482932',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '1.0209760273972603',
#     'ebtperEBIT': '1.0009998571632623',
#     'ebitperRevenue': '0.04765275631819327',
#     'grossProfitMargin': '1.0688007514446933',
#     'operatingProfitMargin': '0.04765275631819327',
#     'pretaxProfitMargin': '0.04770040226794721',
#     'netProfitMargin': '0.04870096721278001',
#     'effectiveTaxRate': '-0.020976027397260275',
#     'returnOnAssets': '0.035416233554096996',
#     'returnOnEquity': '0.27119736193761135',
#     'returnOnCapitalEmployed': '0.04242438932754828',
#     'nIperEBT': '1.0209760273972603',
#     'eBTperEBIT': '1.0009998571632623',
#     'eBITperRevenue': '0.04765275631819327'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.8961680928227564',
#     'payablesTurnover': '-0.5604657610202384',
#     'inventoryTurnover': '-1.3113648157758173',
#     'fixedAssetTurnover': '5.3199956546929315',
#     'assetTurnover': '0.7272182788353975'},
#    'liquidityMeasurementRatios': {'currentRatio': '1.1473934545847635',
#     'quickRatio': '3.0296462448990624',
#     'cashRatio': '0.3909953247034024',
#     'daysOfSalesOutstanding': '192.49348271473008',
#     'daysOfInventoryOutstanding': '-278.3359715077167',
#     'operatingCycle': '-85.84248879298661',
#     'daysOfPayablesOutstanding': '-651.2440641076375',
#     'cashConversionCycle': '843.7375468223677'},
#    'debtRatios': {'debtRatio': '0.8694078979933276',
#     'debtEquityRatio': '6.657430921426676',
#     'longtermDebtToCapitalization': '0.353500453331373',
#     'totalDebtToCapitalization': '1.4426000000029882E10',
#     'interestCoverage': '-47.625850340136054',
#     'cashFlowToDebtRatio': '0.665944015813301',
#     'companyEquityMultiplier': '7.657430921426676'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '2.6478',
#     'freeCashFlowPerShare': '0.9753',
#     'cashPerShare': '3.668',
#     'payoutRatio': '0.21998602375960866',
#     'receivablesTurnover': '1.8961680928227564',
#     'operatingCashFlowSalesRatio': '0.07108775703288252',
#     'freeCashFlowOperatingCashFlowRatio': '0.3683454615090004',
#     'cashFlowCoverageRatios': '0.665944015813301',
#     'shortTermCoverageRatios': '8.308671439936356',
#     'capitalExpenditureCoverageRatios': '1.5831438532666364',
#     'dividendpaidAndCapexCoverageRatios': '1.278178925468119',
#     'dividendPayoutRatio': '0.13168242282272'}},
#   {'date': '2012-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '2.727940890095943',
#     'priceToBookRatio': '2.727940890095943',
#     'priceToSalesRatio': '0.3257172738217567',
#     'priceEarningsRatio': '7.750307032667022',
#     'receivablesTurnover': '1.6313745129414063',
#     'priceToFreeCashFlowsRatio': '12.230102157537251',
#     'priceToOperatingCashFlowsRatio': '4.809560350951907',
#     'priceCashFlowRatio': '4.809560350951907',
#     'priceEarningsToGrowthRatio': '3.8870430256223476',
#     'priceSalesRatio': '0.3257172738217567',
#     'dividendYield': '0.01753923261866085',
#     'enterpriseValueMultiple': '1.6606115211045507',
#     'priceFairValue': '2.727940890095943'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.7347820395339704',
#     'ebtperEBIT': '0.6661724949856109',
#     'ebitperRevenue': '0.0858571867114908',
#     'grossProfitMargin': '0.15363996436032015',
#     'operatingProfitMargin': '0.06674203909882524',
#     'pretaxProfitMargin': '0.05719569628403926',
#     'netProfitMargin': '0.042026370368151905',
#     'effectiveTaxRate': '0.2652179604660296',
#     'returnOnAssets': '0.029634752858937942',
#     'returnOnEquity': '0.35197842854455386',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.7347820395339704',
#     'eBTperEBIT': '0.6661724949856109',
#     'eBITperRevenue': '0.0858571867114908'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.6313745129414063',
#     'payablesTurnover': '5.854516262689041',
#     'inventoryTurnover': '15.354387394729693',
#     'fixedAssetTurnover': '5.35478309678454',
#     'assetTurnover': '0.7051466162634763'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '223.73771142341585',
#     'daysOfInventoryOutstanding': '23.77170710993551',
#     'operatingCycle': '247.50941853335135',
#     'daysOfPayablesOutstanding': '62.34503136085776',
#     'cashConversionCycle': '161.3926800625581'},
#    'debtRatios': {'debtRatio': '0.9138834039048394',
#     'debtEquityRatio': '10.854392675738383',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '2.995559038662487',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '11.877218285570954'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '2.3723582131039764',
#     'freeCashFlowPerShare': '0.93294396506477',
#     'cashPerShare': '4.107104174571052',
#     'payoutRatio': '0.13593443791199003',
#     'receivablesTurnover': '1.6313745129414063',
#     'operatingCashFlowSalesRatio': '0.06772287902724639',
#     'freeCashFlowOperatingCashFlowRatio': '0.39325594250967383',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '-1.6481413994169096',
#     'dividendpaidAndCapexCoverageRatios': '-1.9142857142857144',
#     'dividendPayoutRatio': '0.13593443791199'}},
#   {'date': '2011-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '2.6778720509409104',
#     'priceToBookRatio': '2.6778720509409104',
#     'priceToSalesRatio': '0.2967667945985768',
#     'priceEarningsRatio': '1.9909494474615346',
#     'receivablesTurnover': '1.7265504640888198',
#     'priceToFreeCashFlowsRatio': '7.328912981522492',
#     'priceToOperatingCashFlowsRatio': '4.113150161645544',
#     'priceCashFlowRatio': '4.113150161645544',
#     'priceEarningsToGrowthRatio': '0.995239069380974',
#     'priceSalesRatio': '0.2967667945985768',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '1.7625781257376174',
#     'priceFairValue': '2.6778720509409104'},
#    'profitabilityIndicatorRatios': {'niperEBT': '2.3308348708487086',
#     'ebtperEBIT': '0.6618331679767993',
#     'ebitperRevenue': '0.09662623059621696',
#     'grossProfitMargin': '0.1621916595995723',
#     'operatingProfitMargin': '0.0821946093433133',
#     'pretaxProfitMargin': '0.063950444305151',
#     'netProfitMargin': '0.14905792559271414',
#     'effectiveTaxRate': '-1.3308348708487086',
#     'returnOnAssets': '0.11333460425684616',
#     'returnOnEquity': '1.3450226244343892',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '2.3308348708487086',
#     'eBTperEBIT': '0.6618331679767993',
#     'eBITperRevenue': '0.09662623059621696'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.7265504640888198',
#     'payablesTurnover': '6.410009027307606',
#     'inventoryTurnover': '19.252838501948823',
#     'fixedAssetTurnover': '6.061642304769568',
#     'assetTurnover': '0.7603393365779263'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '211.40418863611225',
#     'daysOfInventoryOutstanding': '18.958243479944723',
#     'operatingCycle': '230.36243211605697',
#     'daysOfPayablesOutstanding': '56.94219749848166',
#     'cashConversionCycle': '154.4619911376306'},
#    'debtRatios': {'debtRatio': '0.9154966694327943',
#     'debtEquityRatio': '10.86485227575193',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '2.9571202888738433',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '11.867713601277615'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '2.574668948085102',
#     'freeCashFlowPerShare': '1.4449618963547932',
#     'cashPerShare': '4.512512583990529',
#     'payoutRatio': '-0.0',
#     'receivablesTurnover': '1.7265504640888198',
#     'operatingCashFlowSalesRatio': '0.07215073190516574',
#     'freeCashFlowOperatingCashFlowRatio': '0.5612224039247752',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '-2.2790589331469833',
#     'dividendpaidAndCapexCoverageRatios': '2.279058933147',
#     'dividendPayoutRatio': '-0'}},
#   {'date': '2010-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '0.0',
#     'priceToBookRatio': '0.0',
#     'priceToSalesRatio': '0.4521',
#     'priceEarningsRatio': '8.8368',
#     'receivablesTurnover': '1.5966',
#     'priceToFreeCashFlowsRatio': '7.8414',
#     'priceToOperatingCashFlowsRatio': '5.0802',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '1.1127395715896',
#     'priceFairValue': ''},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.91723752271774',
#     'ebtperEBIT': '0.53761743705374',
#     'ebitperRevenue': '0.10317632644199',
#     'grossProfitMargin': '0.19001349318362',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.099337748344371',
#     'netProfitMargin': '0.050878607875677',
#     'effectiveTaxRate': '0.082762477282259',
#     'returnOnAssets': '',
#     'returnOnEquity': '-9.7489',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.91723752271774',
#     'eBTperEBIT': '0.53761743705374',
#     'eBITperRevenue': '0.10317632644199'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.5966',
#     'payablesTurnover': '2.1151',
#     'inventoryTurnover': '23.536',
#     'fixedAssetTurnover': '5.5633979032745',
#     'assetTurnover': '0.78302476819664'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '-20.6767',
#     'daysOfInventoryOutstanding': '222.0529',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '46.3121',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.6314',
#     'debtEquityRatio': '-154.5141',
#     'longtermDebtToCapitalization': '',
#     'totalDebtToCapitalization': '',
#     'interestCoverage': '',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': ''},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '3.3276',
#     'freeCashFlowPerShare': '2.1412',
#     'cashPerShare': '4.2925',
#     'payoutRatio': '0.0',
#     'receivablesTurnover': '1.5966',
#     'operatingCashFlowSalesRatio': '0.089000728942103',
#     'freeCashFlowOperatingCashFlowRatio': '0.6434608347129',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '2.8047409579668',
#     'dividendpaidAndCapexCoverageRatios': '2.8047409579668',
#     'dividendPayoutRatio': '-0'}},
#   {'date': '2009-12-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '-3.7553779768388753',
#     'priceToBookRatio': '-3.7553779768388753',
#     'priceToSalesRatio': '0.2525481435711153',
#     'priceEarningsRatio': '10.808632969775488',
#     'receivablesTurnover': '1.399549863996341',
#     'priceToFreeCashFlowsRatio': '2.571996477393589',
#     'priceToOperatingCashFlowsRatio': '1.8974643521922856',
#     'priceCashFlowRatio': '1.8974643521922856',
#     'priceEarningsToGrowthRatio': '4.702083604670744',
#     'priceSalesRatio': '0.2525481435711153',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '0.9019646347540985',
#     'priceFairValue': '-3.7553779768388753'},
#    'profitabilityIndicatorRatios': {'niperEBT': '1.043394777265745',
#     'ebtperEBIT': '0.27719821162444114',
#     'ebitperRevenue': '0.08078566944437278',
#     'grossProfitMargin': '0.14978113739755597',
#     'operatingProfitMargin': '0.02887782392955118',
#     'pretaxProfitMargin': '0.022393643094863393',
#     'netProfitMargin': '0.023365410249133578',
#     'effectiveTaxRate': '-0.043394777265745005',
#     'returnOnAssets': '0.014148094147052698',
#     'returnOnEquity': '-0.34744245524296674',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '1.043394777265745',
#     'eBTperEBIT': '0.27719821162444114',
#     'eBITperRevenue': '0.08078566944437278'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '1.399549863996341',
#     'payablesTurnover': '6.913222851548842',
#     'inventoryTurnover': '19.612378496330095',
#     'fixedAssetTurnover': '5.136855590405089',
#     'assetTurnover': '0.6055144761508019'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '260.798139022901',
#     'daysOfInventoryOutstanding': '18.610695284526532',
#     'operatingCycle': '279.4088343074275',
#     'daysOfPayablesOutstanding': '52.797372200756584',
#     'cashConversionCycle': '208.00076682214444'},
#    'debtRatios': {'debtRatio': '1.0405228077483857',
#     'debtEquityRatio': '-25.552685421994884',
#     'longtermDebtToCapitalization': '',
#     'totalDebtToCapitalization': '',
#     'interestCoverage': '1.3835051546391752',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '-24.55754475703325'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '4.679929817780375',
#     'freeCashFlowPerShare': '3.4525708250575904',
#     'cashPerShare': '6.317920372985925',
#     'payoutRatio': '-0.0',
#     'receivablesTurnover': '1.399549863996341',
#     'operatingCashFlowSalesRatio': '0.13309770129769613',
#     'freeCashFlowOperatingCashFlowRatio': '0.7377398720682303',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '-3.813008130081301',
#     'dividendpaidAndCapexCoverageRatios': '3.8130081300813',
#     'dividendPayoutRatio': '-0'}}]}

# %%
fr['symbol']
# Out:
# 'F'

# %%
len(fr['ratios'])
# Out:
# 10

# %%
for i in range(len(fr['ratios'])):
    print(fr['ratios'][i]['date'])
# Out:
# 2018-12-31
# 2017-12-31
# 2016-12-31
# 2015-12-31
# 2014-12-31
# 2013-12-31
# 2012-12-31
# 2011-12-31
# 2010-12-31
# 2009-12-31

# %%
for i in range(len(fr['ratios'])):
    print(fr['ratios'][i]['cashFlowIndicatorRatios']['cashPerShare'])
# Out:
# 4.2027
# 4.6552
# 4.0026
# 3.5962
# 2.795
# 3.668
# 4.107104174571052
# 4.512512583990529
# 4.2925
# 6.317920372985925
